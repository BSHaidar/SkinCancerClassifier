# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import auc,roc_curve
import cv2
import os
from glob import glob

# %%
# !pwd
# Out:
# /Users/basselhaidar/Desktop/Final Project/SkinCancerClassifier

# %%
data_dir = '../skin-cancer-mnist-ham10000/'

# %%
print(os.listdir(data_dir))
# Out:
# ['hmnist_28_28_L.csv', '.DS_Store', 'HAM10000_images_part_1.zip', 'HAM10000_images_part_2.zip', 'hmnist_28_28_RGB.csv', 'HAM10000_images_part_1', 'hmnist_8_8_RGB.csv', 'hmnist_8_8_L.csv', 'HAM10000_images_part_2', 'HAM10000_metadata.csv']

# %%
pd.options.display.max_columns = 2400

# %%
toto = pd.read_csv(data_dir + 'HAM10000_metadata.csv')
toto.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear

# %%
print(os.path.basename('../skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291.jpg'))
# Out:
# ISIC_0029291.jpg

# %%
! ls
# Out:
# Skin Cancer Classifier Notebook.ipynb

# %%
glob('*.ipynb')
# Out:
# ['Skin Cancer Classifier Notebook.ipynb']

# %%
img_path = '../skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291.jpg'

# %%
os.path.splitext(img_path)
# Out:
# ('../skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291', '.jpg')

# %%
os.path.join(data_dir, '*', '*.jpg')
# Out:
# '../skin-cancer-mnist-ham10000/*/*.jpg'

# %%
len(glob(os.path.join(data_dir, '*', '*.jpg')))
# Out:
# 10015

# %%
test_var = os.path.basename('../skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291.jpg')
test_var
# Out:
# 'ISIC_0029291.jpg'

# %%
os.path.realpath('../skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291.jpg')
# Out:
# '/Users/basselhaidar/Desktop/Final Project/skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291.jpg'

# %%
os.path.relpath('../skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291.jpg')
# Out:
# '../skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291.jpg'

# %%
toto = os.path.dirname(data_dir)
toto
# Out:
# '../skin-cancer-mnist-ham10000'

# %%
image_file_path_dict = {os.path.splitext(os.path.basename(x))[0]: x
                     for x in glob(os.path.join(data_dir, '*', '*.jpg'))}

# %%
image_file_path_dict = {os.path.splitext(os.path.basename(x))[0]: x
                     for x in glob(os.path.join(data_dir, '*', '*.jpg'))}

# %%
os.path.splitext('../skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291.jpg')
# Out:
# ('../skin-cancer-mnist-ham10000/HAM10000_images_part_1/ISIC_0029291', '.jpg')

# %%
os.path.splitext('../skin-cancer-mnist-ham10000/HAM10000_images_part_1/')
# Out:
# ('../skin-cancer-mnist-ham10000/HAM10000_images_part_1/', '')

# %% [markdown]
# ###### Diagnostic categories in the realm of pigmented lesions: Actinic keratoses and intraepithelial carcinoma / Bowen's disease (akiec), basal cell carcinoma (bcc), benign keratosis-like lesions (solar lentigines / seborrheic keratoses and lichen-planus like keratoses, bkl), dermatofibroma (df), melanoma (mel), melanocytic nevi (nv) and vascular lesions (angiomas, angiokeratomas, pyogenic granulomas and hemorrhage, vasc).

# %%
# Create dictionary to display label names instead of numbers 0 through 6
skin_lesion_type_dict = {
   
    'akiec': 'Actinic keratoses and intraepithelial carcinoma / Bowen disease',
    'bcc': 'Basal cell carcinoma',
    'bkl': 'Benign keratosis-like lesions (solar lentigines / seborrheic keratoses and lichen-planus like keratoses, bkl)',
    'df': 'Dermatofibroma',
    'mel': 'Melanoma',
    'nv': 'Melanocytic nevi',
    'vasc': 'Vascular lesions(angiomas, angiokeratomas, pyogenic granulomas and hemorrhage, vasc)',
    
}

# %%
h_28_l = pd.read_csv(data_dir + 'hmnist_28_28_L.csv')
h_28_rgb = pd.read_csv(data_dir + 'hmnist_28_28_RGB.csv')
h_8_l = pd.read_csv(data_dir + 'hmnist_8_8_L.csv')
h_8_rgb = pd.read_csv(data_dir + 'hmnist_8_8_RGB.csv')

# %%
h_28_rgb = pd.read_csv(data_dir + 'hmnist_28_28_RGB.csv')

# %%
def df_info(df):
    print("\nLabels unique values {}, length {}\n\n".format(df.label.unique(), len(h_28_l)))
    print(df.head())

# %%
df_info(h_28_l)
# Out:
# Labels unique values [2 4 3 6 5 1 0], length 10015
#
#
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        169        171        170        177        181        182
# 1         19         57        105        140        149        148
# 2        155        163        161        167        167        172
# 3         25         71        116        139        136        153
# 4        129        162        181        196        205        208
#
#    pixel0006  pixel0007  pixel0008  pixel0009  pixel0010  pixel0011  \
# 0        181        185        194        192        188        190
# 1        144        155        170        170        182        183
# 2        155        152        165        175        175        164
# 3        148        161        172        162        159        176
# 4        205        213        225        224        222        227
#
#    pixel0012  pixel0013  pixel0014  pixel0015  pixel0016  pixel0017  \
# ...

# %%
df_info(h_28_rgb)
# Out:
# Labels unique values [2 4 3 6 5 1 0], length 10015
#
#
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  pixel0010  pixel0011  \
# 0        197        154        185        202        162        192
# 1        123         93        126        158        128        158
# 2        201        142        160        206        149        165
# 3        143        103        119        171        125        134
# 4        215        162        191        225        179        214
#
#    pixel0012  pixel0013  pixel0014  pixel0015  pixel0016  pixel0017  \
# ...

# %%
df_info(h_8_l)
# Out:
# Labels unique values [2 4 3 6 5 1 0], length 10015
#
#
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        172        182        191        183        180        181
# 1         98        149        170        193        183        162
# 2        165        164        179        172        152        163
# 3        109        159        167        166        163        159
# 4        173        202        210        194        208        248
#
#    pixel0006  pixel0007  pixel0008  pixel0009  pixel0010  pixel0011  \
# 0        165        164        173        192        201        172
# 1        164        100        137        175        193        195
# 2        169        151        168        174        184        172
# 3        155         96        141        168        174        181
# 4        243        205        180        142        129        136
#
#    pixel0012  pixel0013  pixel0014  pixel0015  pixel0016  pixel0017  \
# ...

# %%
df_info(h_8_rgb)
# Out:
# Labels unique values [2 4 3 6 5 1 0], length 10015
#
#
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        199        156        188        210        165        198
# 1        115         87        115        180        133        158
# 2        203        146        164        209        144        153
# 3        135         96        110        198        141        156
# 4        204        156        187        232        185        216
#
#    pixel0006  pixel0007  pixel0008  pixel0009  pixel0010  pixel0011  \
# 0        216        176        203        215        166        193
# 1        200        153        187        215        179        213
# 2        217        160        181        215        151        173
# 3        208        148        158        210        147        154
# 4        236        196        220        217        182        202
#
#    pixel0012  pixel0013  pixel0014  pixel0015  pixel0016  pixel0017  \
# ...
